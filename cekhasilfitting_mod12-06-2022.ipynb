# %%
import os
import cmath #To help us out with the complex square root
import numpy as np #For the arrays
import matplotlib.pyplot as plt #Visualization

# %%
# # yg ini salah


# ################################################################################################################

# EOS & anisotropy NS Matter based on GUP; case beta=0
def eden_beta0e0_old(P0): 
    if P0>50. :
        FED = 252.7351203007992e0 + 2.0517873998109133e0*P0
    elif P0 > 0.5658 and P0 <= 50. :
        FED = 40.72822519163616e0 + 172.88564172842007e0*P0 - 129.75665741187734e0*P0**2 + 57.21198616046201e0*P0**3 - 15.6150708008523e0*P0**4 + 2.8354313027185887e0*P0**5 - 0.3602847077751246e0*P0**6 + 0.03316049472454524e0*P0**7 - 0.0022626453096747964e0*P0**8 + 0.00011613173543073938e0*P0**9 - 4.5162772145274745e-6*P0**10 + 1.3312210942573273e-7*P0**11 - 2.952609024402367e-9*P0**12 + 4.845080539678656e-11*P0**13 - 5.701316398676422e-13*P0**14 + 4.5477089999551786e-15*P0**15 - 2.2015407469797255e-17*P0**16 + 4.881799449675595e-20*P0**17
    elif P0 > 4.99313436e-4 and P0 <= 0.5658 :
        FED = 0.2138614869659046e0 + 768.9378464621362e0*P0 - 6179.085226412627e0*P0**2 + 31192.024180740616e0*P0**3 - 85373.61029759394e0*P0**4 + 117008.53995402799e0*P0**5 - 62844.457041598056e0*P0**6
    else :
        FED = 0.00020663104786823767e0 + 985.7550962048155e0*P0 - 6.452649548410661e6*P0**2 + 4.045493650683346e10*P0**3 - 1.2422017897554195e14*P0**4 + 1.765493095354902e17*P0**5 - 9.1529417012139e19*P0**6
    return FED
def sig_beta0e0_old(P0,PCC):
    sig = 0.
    return sig

# EOS & anisotropy NS Matter based on GUP; case beta=1e-9
def eden_beta1e_9_old(P0): 
    if P0>50. :
        FED = 252.78278962148056e0 + 2.050868961120045e0*P0
    elif P0 > 0.5658 and P0 <= 50. :
        FED = 40.15034086505595e0 + 177.5866219617547e0*P0 - 137.00971748612557e0*P0**2 + 61.89954941513774e0*P0**3 - 17.26901975343054e0*P0**4 + 3.19828292723069e0*P0**5 - 0.41368745512340627e0*P0**6 + 0.0386929339507851e0*P0**7 - 0.002678910218415325e0*P0**8 + 0.0001393320273523317e0*P0**9 - 5.4844862695484765e-6*P0**10 + 1.634623232394756e-7*P0**11 - 3.662635167044916e-9*P0**12 + 6.066820918324125e-11*P0**13 - 7.201085144548133e-13*P0**14 + 5.7902998474439245e-15*P0**15 - 2.824048011545469e-17*P0**16 + 6.305773287870958e-20*P0**17
    elif P0 > 4.99313436e-4 and P0 <= 0.5658 :
        FED = 0.13875280004543208e0 + 803.3119721991872e0*P0 - 7604.053978101671e0*P0**2 + 50338.552627037454e0*P0**3 - 199754.51797965978e0*P0**4 + 454007.45145368035e0*P0**5 - 542329.881379661e0*P0**6 + 262911.3019837204e0*P0**7
    elif P0 >= 0. and P0 <= 4.99313436e-4 :
        FED = 0.00020663104786823767e0 + 985.7550962048155e0*P0 - 6.452649548410661e6*P0**2 + 4.045493650683346e10*P0**3 - 1.2422017897554195e14*P0**4 + 1.765493095354902e17*P0**5 - 9.1529417012139e19*P0**6
    else :
        FED = 0.
    return FED
def sig_beta1e_9_old(P0,PCC):
    sig = 0.0009109253091662184e0 + 0.0006614884992791607e0*P0 - 2.562440474996395e-6*P0**2 + 1.2369135151340834e-8*P0**3 - 2.5518866105304432e-11*P0**4 + 2.542548182407993e-14*P0**5 - 9.800236597274048e-18*P0**6
    if P0 == PCC: sig = 0.
    return sig

# EOS & anisotropy NS Matter based on GUP; case beta=1e-8
def eden_beta1e_8_old(P0): 
    if P0>50. :
        FED = 253.2167266972223e0 + 2.042574552844379e0*P0
    elif P0 > 0.5658 and P0 <= 50. :
        FED = 34.996719907638656e0 + 217.38861380763586e0*P0 - 197.7847221323045e0*P0**2 + 100.96604597400824e0*P0**3 - 31.000998206090017e0*P0**4 + 6.201685436984379e0*P0**5 - 0.8545436764597708e0*P0**6 + 0.08425535863251823e0*P0**7 - 0.006099401533513903e0*P0**8 + 0.000329567312119461e0*P0**9 - 0.000013407358939926027e0*P0**10 + 4.112479560545507e-7*P0**11 - 9.450222969553151e-9*P0**12 + 1.6006796160515572e-10*P0**13 - 1.9380539806762782e-12*P0**14 + 1.5862872432492548e-14*P0**15 - 7.861083316562445e-17*P0**16 + 1.7807392264595506e-19*P0**17
    elif P0 > 4.99313436e-4 and P0 <= 0.5658 :
        FED = 0.25227973223585715e0 + 785.6239013862972e0*P0 - 7097.193231748922e0*P0**2 + 44787.78752904974e0*P0**3 - 170674.67647877714e0*P0**4 + 375798.1030069276e0*P0**5 - 438222.42374165234e0*P0**6 + 208628.4521716856e0*P0**7
    elif P0 >= 0. and P0 <= 4.99313436e-4 :
        FED = 0.00020663104786823767e0 + 985.7550962048155e0*P0 - 6.452649548410661e6*P0**2 + 4.045493650683346e10*P0**3 - 1.2422017897554195e14*P0**4 + 1.765493095354902e17*P0**5 - 9.1529417012139e19*P0**6
    else :
        FED = 0.
    return FED
def sig_beta1e_8_old(P0,PCC):
    sig = 0.00893216184253268e0 + 0.0066138230853899135e0*P0 - 0.00002547856239766327e0*P0**2 + 1.227701424673366e-7*P0**3 - 2.525768285081147e-10*P0**4 + 2.5092894933230487e-13*P0**5 - 9.644098826004996e-17*P0**6
    if P0 == PCC: sig = 0.
    return sig

# EOS & anisotropy NS Matter based on GUP; case beta=1e-7
def eden_beta1e_7_old(P0): 
    if P0>50. :
        FED = 257.9799384090066e0 + 1.9569165063025655e0*P0
    elif P0 > 0.5658 and P0 <= 50. :
        FED = 26.792963384820982e0 + 212.32723839848072e0*P0 - 183.05922154778605e0*P0**2 + 89.85873533958548e0*P0**3 - 26.782581281061287e0*P0**4 + 5.234534531022756e0*P0**5 - 0.7079405866302086e0*P0**6 + 0.0687440360332156e0*P0**7 - 0.004913868423197951e0*P0**8 + 0.00026269453845358007e0*P0**9 - 0.000010590337777766127e0*P0**10 + 3.2231720681360846e-7*P0**11 - 7.356748971512561e-9*P0**12 + 1.2387524537448806e-10*P0**13 - 1.4920818654276785e-12*P0**14 + 1.2156733044662518e-14*P0**15 - 5.999956952734376e-17*P0**16 + 1.3542143049639314e-19*P0**17
    elif P0 > 4.99313436e-4 and P0 <= 0.5658 :
        FED = 1.9556157223144337e0 + 510.1571753657856e0*P0 - 1731.0073225480944e0*P0**2 + 2942.342342591839e0*P0**3 - 1842.4124908739573e0*P0**4
    elif P0 >= 0. and P0 <= 4.99313436e-4 :
        FED = 0.00020663104786823767e0 + 985.7550962048155e0*P0 - 6.452649548410661e6*P0**2 + 4.045493650683346e10*P0**3 - 1.2422017897554195e14*P0**4 + 1.765493095354902e17*P0**5 - 9.1529417012139e19*P0**6
    else :
        FED = 0.
    return FED
def sig_beta1e_7_old(P0,PCC):
    sig = 0.07155239813179404e0 + 0.06606791761347486e0*P0 - 0.00024112533580554287e0*P0**2 + 1.143510757936114e-6*P0**3 - 2.2910564964032e-9*P0**4 + 2.2151475945322894e-12*P0**5 - 8.284546815733482e-16*P0**6 
    if P0 == PCC: sig = 0.
    return sig

# ################################################################################################################

# %%
# # berikut yang benar, eh ternyata salah juga -____-


# EOS & anisotropy NS Matter based on GUP; case beta=0
def eden_beta0e0_old2(P0): 
    if P0 > 50.000000000000 :
        FED = 253.96691872794116 + 3.2796161800906884*P0 - 0.0020158642583399293*P0**2 + 1.8708497596280787e-6*P0**3
    elif P0 > 0.5658 and P0 <= 50. :
        FED = 16.31037431332163 + 148.39390464493556*P0 - 128.93753020320776*P0**2 + 68.2356918893135*P0**3 - 21.650332690422154*P0**4 + 4.4465227656365665*P0**5 - 0.6259853713675084*P0**6 + 0.06284645834927154*P0**7 - 0.004621547902109509*P0**8 + 0.00025322629002273446*P0**9 - 0.000010433050114526842*P0**10 + 3.2377771361151826e-7*P0**11 - 7.521885797105986e-9*P0**12 + 1.2872591146204104e-10*P0**13 - 1.5739511567565022e-12*P0**14 + 1.3004605578806233e-14*P0**15 - 6.503456220814279e-17*P0**16 + 1.4862400432404175e-19*P0**17
    elif P0 > 4.99313436e-4 and P0 <= 0.5658 :
        FED = 0.23039137132817475 + 767.6465603936995*P0 - 6155.467776192405*P0**2 + 31022.166606827268*P0**3 - 84807.05654084905*P0**4 + 116127.95920165074*P0**5 - 62328.876658927344*P0**6
    else :
        FED = 0.00020663104786823767 + 985.7550962048155*P0 - 6.452649548410661e6*P0**2 + 4.045493650683346e10*P0**3 - 1.2422017897554195e14*P0**4 + 1.765493095354902e17*P0**5 - 9.1529417012139e19*P0**6
    return FED
def sig_beta0e0_old2(P0,PCC):
    sig = 0.
    return sig

# EOS & anisotropy NS Matter based on GUP; case beta=1e-7
def eden_beta1e_7_old2(P0): 
    if P0>50. :
        FED = 250.45493278099934 + 3.187377839824209*P0 - 0.0020285944059716204*P0**2 + 1.7493061609160738e-6*P0**3
    elif P0 > 0.5658 and P0 <= 50. :
        FED = 6.030867335549392 + 103.39669888062852*P0 - 75.0937160928083*P0**2 + 38.69845989941432*P0**3 - 12.240315545472527*P0**4 + 2.5175407042680122*P0**5 - 0.3553092981629523*P0**6 + 0.03576849448033916*P0**7 - 0.0026373695172572397*P0**8 + 0.00014488091399527585*P0**9 - 5.983849933996567e-6*P0**10 + 1.8613705401421867e-7*P0**11 - 4.333938117120106e-9*P0**12 + 7.432766310979864e-11*P0**13 - 9.106834990518573e-13*P0**14 + 7.539327710297994e-15*P0**15 - 3.7775499581280234e-17*P0**16 + 8.64888654742912e-20*P0**17
    elif P0 > 4.99313436e-4 and P0 <= 0.5658 :
        FED = 0.0757687586830372 + 829.9497847043751*P0 - 9051.617135498653*P0**2 + 77241.18715250143*P0**3 - 430894.58551173063*P0**4 + 1.4910956678299124e6*P0**5 - 3.049414706512929e6*P0**6 + 3.3525846226876033e6*P0**7 - 1.5206858202208828e6*P0**8
    elif P0 >= 0. and P0 <= 4.99313436e-4 :
        FED = 0.00020663104786823767 + 985.7550962048155*P0 - 6.452649548410661e6*P0**2 + 4.045493650683346e10*P0**3 - 1.2422017897554195e14*P0**4 + 1.765493095354902e17*P0**5 - 9.1529417012139e19*P0**6
    else :
        FED = 0.
    return FED
def sig_beta1e_7_old2(P0,PCC):
    if P0 == PCC: sig = 0.
    else:
        sig = 0.03276270690402336 + 0.07327241846780143*P0 - 0.00028451388654869347*P0**2 + 1.8992654822039604e-6*P0**3 - 5.542478357273098e-9*P0**4 + 7.919729184669515e-12*P0**5 - 4.411910834615518e-15*P0**6
    return sig

# EOS & anisotropy NS Matter based on GUP; case beta=1e-8
def eden_beta1e_8_old2(P0): 
    if P0>50. :
        FED = 253.71368196542912 + 3.269206654347735*P0 - 0.0020125641881387902*P0**2 + 1.853502452555778e-6*P0**3
    elif P0 > 0.5658 and P0 <= 50. :
        FED = 14.144860554883346 + 144.85782235609184*P0 - 122.91473866410261*P0**2 + 64.34716023870452*P0**3 - 20.27491468185057*P0**4 + 4.141880893766522*P0**5 - 0.5804845302552107*P0**6 + 0.05804595834702129*P0**7 - 0.004252849619862879*P0**8 + 0.00023221722825744385*P0**9 - 9.535734891545676e-6*P0**10 + 2.9498061813261156e-7*P0**11 - 6.831427418961262e-9*P0**12 + 1.1655078323739455e-10*P0**13 - 1.4207753244137239e-12*P0**14 + 1.1703949201970065e-14*P0**15 - 5.835707529007417e-17*P0**16 + 1.3297281233470024e-19*P0**17
    elif P0 > 4.99313436e-4 and P0 <= 0.5658 :
        FED = 0.14573492826313872 + 802.531308180131*P0 - 7583.658621878336*P0**2 + 50124.50144466164*P0**3 - 198659.78521340183*P0**4 + 451107.75552429585*P0**5 - 538509.8939078312*P0**6 + 260934.2900444301*P0**7
    elif P0 >= 0. and P0 <= 4.99313436e-4 :
        FED = 0.00020663104786823767 + 985.7550962048155*P0 - 6.452649548410661e6*P0**2 + 4.045493650683346e10*P0**3 - 1.2422017897554195e14*P0**4 + 1.765493095354902e17*P0**5 - 9.1529417012139e19*P0**6
    else :
        FED = 0.
    return FED
def sig_beta1e_8_old2(P0,PCC):
    sig = 0.007047263002062659 + 0.00735756800407128*P0 - 0.00003045736308770188*P0**2 + 2.0892657642809882e-7*P0**3 - 6.321235153591142e-10*P0**4 + 9.365561598013124e-13*P0**5 - 5.407853093925551e-16*P0**6
    if P0 == PCC: sig = 0.
    return sig

# EOS & anisotropy NS Matter based on GUP; case beta=1e-9
def eden_beta1e_9_old2(P0): 
    if P0>50. :
        FED = 253.94165017555784 + 3.278574239142177*P0 - 0.002015524955731631*P0**2 + 1.8690995783165108e-6*P0**3
    elif P0 > 0.5658 and P0 <= 50. :
        FED = 16.075121339927 + 148.09665273078753*P0 - 128.3926633259865*P0**2 + 67.87615319741464*P0**3 - 21.521594835944757*P0**4 + 4.417763125081451*P0**5 - 0.621660852287162*P0**6 + 0.06238761678267705*P0**7 - 0.004586131646254469*P0**8 + 0.0002511991595509348*P0**9 - 0.000010346112728809987*P0**10 + 3.2097696018251097e-7*P0**11 - 7.454490385259677e-9*P0**12 + 1.275334293049657e-10*P0**13 - 1.5588994612416293e-12*P0**14 + 1.2876397515152669e-14*P0**15 - 6.437436824233298e-17*P0**16 + 1.470720972217311e-19*P0**17
    elif P0 > 4.99313436e-4 and P0 <= 0.5658 :
        FED = 0.14826521659545558 + 802.2341079865328*P0 - 7575.771664752471*P0**2 + 50041.109820925776*P0**3 - 198231.47362058455*P0**4 + 449970.1766095602*P0**5 - 537008.4954293505*P0**6 + 260156.21589864962*P0**7
    elif P0 >= 0. and P0 <= 4.99313436e-4 :
        FED = 0.00020663104786823767 + 985.7550962048155*P0 - 6.452649548410661e6*P0**2 + 4.045493650683346e10*P0**3 - 1.2422017897554195e14*P0**4 + 1.765493095354902e17*P0**5 - 9.1529417012139e19*P0**6
    else :
        FED = 0.
    return FED
def sig_beta1e_9_old2(P0,PCC):
    sig = 0.0007421020716274194 + 0.0007360498485325017*P0 - 3.066382135041652e-6*P0**2 + 2.1094050479547643e-8*P0**3 - 6.405883199257302e-11*P0**4 + 9.526370137661429e-14*P0**5 - 5.5210560366104195e-17*P0**6
    if P0 == PCC: sig = 0.
    return sig

# %%
# hasil fitting terbaru 2022-03-07

# EOS & anisotropy NS Matter based on GUP; case beta=0
def eden_beta0e0_old3(P0): 
    if P0 > 50.000000000000 :
        FED = 254.57247440600335 + 3.2722668135019912*P0 - 0.0019902480708849125*P0**2 + 1.843962716723806e-6*P0**3
    elif P0 > 0.5658 and P0 <= 50. :
        FED = 49.26785125407585 + 39.11737020657924*P0 - 6.016128303060254*P0**2 + 0.3414923990896232*P0**3 + 0.18952907983055753*P0**4 - 0.06660361609394749*P0**5 + 0.01151087018516792*P0**6 - 0.0012890911262028622*P0**7 + 0.00010152320471437593*P0**8 - 5.8358103065480955e-6*P0**9 + 2.493373166744397e-7*P0**10 - 7.968694825132823e-9*P0**11 + 1.898165892923205e-10*P0**12 - 3.3213117284620262e-12*P0**13 + 4.144329953328089e-14*P0**14 - 3.490034358766075e-16*P0**15 + 1.7773505419267266e-18*P0**16 - 4.133909658617962e-21*P0**17
    elif P0 > 4.99313436e-4 and P0 <= 0.5658 :
        FED = 0.42600647956391097 + 714.239562187894*P0 - 4571.210848278951*P0**2 + 16153.31540875086*P0**3 - 26410.273422295468*P0**4 + 15662.08708827156*P0**5
    else :
        FED = 0.00023360915782327885 + 963.9682663375576*P0 - 6.022287440793628e6*P0**2 + 3.8959199862096825e10*P0**3 - 1.299108445236239e14*P0**4 + 2.097713931761943e17*P0**5 - 1.297185952864878e20*P0**6
    return FED
def sig_beta0e0_old3(P0,PCC):
    sig = 0.
    return sig

# EOS & anisotropy NS Matter based on GUP; case beta=1e-7
def eden_beta1e_7_old3(P0): 
    if P0>50. :
        FED = 251.0731948102463 + 3.1800886693528474*P0 - 0.0020040035670855975*P0**2 + 1.7243713851215077e-6*P0**3
    elif P0 > 0.5658 and P0 <= 50. :
        FED = 67.35232299097427 - 59.58608956261303*P0 + 82.73071434070408*P0**2 - 39.401804870651645*P0**3 + 10.799526030864467*P0**4 - 1.9127094225450478*P0**5 + 0.2325906052895863*P0**6 - 0.02016303442928495*P0**7 + 0.0012759522939388612*P0**8 - 0.00005974712607258074*P0**9 + 2.0802766496377973e-6*P0**10 - 5.364964392428233e-8*P0**11 + 1.0102710104459873e-9*P0**12 - 1.3491472660135368e-11*P0**13 + 1.2097649197990256e-13*P0**14 - 6.529896777665812e-16*P0**15 + 1.6030422858314032e-18*P0**16
    elif P0 > 4.99313436e-4 and P0 <= 0.5658 :
        FED = 0.6596556980482654 + 658.7820465828245*P0 - 3385.412057495701*P0**2 + 8513.26060947245*P0**3 - 7598.179318111917*P0**4
    elif P0 >= 0. and P0 <= 4.99313436e-4 :
        FED = 0.00023360915782327885 + 963.9682663375576*P0 - 6.022287440793628e6*P0**2 + 3.8959199862096825e10*P0**3 - 1.299108445236239e14*P0**4 + 2.097713931761943e17*P0**5 - 1.297185952864878e20*P0**6
    else :
        FED = 0.
    return FED
def sig_beta1e_7_old3(P0,PCC):
    if P0 == PCC: sig = 0.
    else:
        sig = 0.03276270690402464 + 0.0732724184678019*P0 - 0.0002845138865487051*P0**2 + 1.899265482204056e-6*P0**3 - 5.542478357273446e-9*P0**4 + 7.919729184670085e-12*P0**5 - 4.411910834615863e-15*P0**6
    return sig

# EOS & anisotropy NS Matter based on GUP; case beta=1e-8
def eden_beta1e_8_old3(P0): 
    if P0>50. :
        FED = 254.31973251671707 + 3.261877526932941*P0 - 0.001987113156914036*P0**2 + 1.8268897540295154e-6*P0**3
    elif P0 > 0.5658 and P0 <= 50. :
        FED = 50.988731956384235 + 28.78265687086006*P0 + 3.522828894114323*P0**2 - 3.9081486989415053*P0**3 + 1.2919277799792201*P0**4 - 0.24898629632433356*P0**5 + 0.03176797506534037*P0**6 - 0.0028394364130570372*P0**7 + 0.00018344054597179885*P0**8 - 8.71513642334962e-6*P0**9 + 3.0660028823407204e-7*P0**10 - 7.966067022490301e-9*P0**11 + 1.5080426947997883e-10*P0**12 - 2.0213252641951495e-12*P0**13 + 1.8169434506799985e-14*P0**14 - 9.821725463730458e-17*P0**15 + 2.4128466579501887e-19*P0**16
    elif P0 > 4.99313436e-4 and P0 <= 0.5658 :
        FED = 0.6596556980482654 + 658.7820465828245*P0 - 3385.412057495701*P0**2 + 8513.26060947245*P0**3 - 7598.179318111917*P0**4
    elif P0 >= 0. and P0 <= 4.99313436e-4 :
        FED = 0.00023360915782327885 + 963.9682663375576*P0 - 6.022287440793628e6*P0**2 + 3.8959199862096825e10*P0**3 - 1.299108445236239e14*P0**4 + 2.097713931761943e17*P0**5 - 1.297185952864878e20*P0**6
    else :
        FED = 0.
    return FED
def sig_beta1e_8_old3(P0,PCC):
    if P0 == PCC: sig = 0.
    else:
        sig = 0.007047263002061006 + 0.007357568004071337*P0 - 0.000030457363087701862*P0**2 + 2.089265764280977e-7*P0**3 - 6.321235153591108e-10*P0**4 + 9.365561598013083e-13*P0**5 - 5.407853093925535e-16*P0**6
    return sig

# EOS & anisotropy NS Matter based on GUP; case beta=1e-9
def eden_beta1e_9_old3(P0): 
    if P0>50. :
        FED = 254.5472555851451 + 3.2712269037830373*P0 - 0.001989925377727716*P0**2 + 1.842240175748262e-6*P0**3
    elif P0 > 0.5658 and P0 <= 50. :
        FED = 49.36451605135995 + 38.67136097896892*P0 - 5.971069558588728*P0**2 + 0.5280838892749922*P0**3 + 0.07213453678089991*P0**4 - 0.031943274585310134*P0**5 + 0.005286912083808431*P0**6 - 0.0005395931912018858*P0**7 + 0.00003781696563768739*P0**8 - 1.8989989196820048e-6*P0**9 + 6.955646370720643e-8*P0**10 - 1.8637558378162894e-9*P0**11 + 3.615446496719337e-11*P0**12 - 4.943504224112297e-13*P0**13 + 4.5182176197666075e-15*P0**14 - 2.4772670118351236e-17*P0**15 + 6.161038224459982e-20*P0**16
    elif P0 > 4.99313436e-4 and P0 <= 0.5658 :
        FED = 0.6596556980482654 + 658.7820465828245*P0 - 3385.412057495701*P0**2 + 8513.26060947245*P0**3 - 7598.179318111917*P0**4
    elif P0 >= 0. and P0 <= 4.99313436e-4 :
        FED = 0.00023360915782327885 + 963.9682663375576*P0 - 6.022287440793628e6*P0**2 + 3.8959199862096825e10*P0**3 - 1.299108445236239e14*P0**4 + 2.097713931761943e17*P0**5 - 1.297185952864878e20*P0**6
    else :
        FED = 0.
    return FED
def sig_beta1e_9_old3(P0,PCC):
    if P0 == PCC: sig = 0.
    else:
        sig = 0.0007421020716274209 + 0.0007360498485325009*P0 - 3.066382135041724e-6*P0**2 + 2.1094050479548345e-8*P0**3 - 6.405883199257561e-11*P0**4 + 9.526370137661879e-14*P0**5 - 5.5210560366107184e-17*P0**6
    return sig

# %%
# hasil fitting terbaru 2022-03-15

# EOS & anisotropy NS Matter based on GUP; case beta=0
def eden_beta0e0_old4(P0): 
    if P0 > 50.000000000000 :
        FED = 254.57247440600344 + 3.2722668135019894*P0 - 0.0019902480708849034*P0**2 + 1.8439627167238033e-6*P0**3
    elif P0 > 0.5658 and P0 <= 50. :
        FED = 49.267245301992 + 39.12015287002968*P0 - 6.020094633721215*P0**2 + 0.3441152374080011*P0**3 + 0.1885554331444731*P0**4 - 0.06637720355881765*P0**5 + 0.011475525194044604*P0**6 - 0.0012852136878535097*P0**7 + 0.00010121502625294346*P0**8 - 5.817713041305554e-6*P0**9 + 2.485435214623891e-7*P0**10 - 7.942609315374174e-9*P0**11 + 1.8917771422067206e-10*P0**12 - 3.3098276551326267e-12*P0**13 + 4.129626534967556e-14*P0**14 - 3.477346789547739e-16*P0**15 + 1.770739061738443e-18*P0**16 - 4.11819633746566e-21*P0**17
    elif P0 > 4.99313436e-4 and P0 <= 0.5658 :
        FED = 0.4260064795640439 + 714.2395621878875*P0 - 4571.210848278883*P0**2 + 16153.315408750519*P0**3 - 26410.273422294766*P0**4 + 15662.087088271082*P0**5
    else :
        FED = 0.00023360915782327885 + 963.9682663375576*P0 - 6.022287440793628e6*P0**2 + 3.8959199862096825e10*P0**3 - 1.299108445236239e14*P0**4 + 2.097713931761943e17*P0**5 - 1.297185952864878e20*P0**6
    return FED
def sig_beta0e0_old4(P0,PCC):
    sig = 0.
    return sig

# EOS & anisotropy NS Matter based on GUP; case beta=1e-7
def eden_beta1e_7_old4(P0): 
    if P0>50. :
        FED = 253.6316521603898 + 3.2752062368565222*P0 - 0.0020475370384748586*P0**2 + 1.9042736185326143e-6*P0**3
    elif P0 > 0.5658 and P0 <= 50. :
        FED = 66.96695430515722 - 56.51414470005744*P0 + 80.53182092659665*P0**2 - 38.23653809705289*P0**3 + 10.427869506304706*P0**4 - 1.8375616323890898*P0**5 + 0.22236002007323272*P0**6 - 0.019184652205875004*P0**7 + 0.0012083962470858635*P0**8 - 0.0000563245410342902*P0**9 + 1.9522095644462132e-6*P0**10 - 5.011982059094741e-8*P0**11 + 9.395640729971063e-10*P0**12 - 1.24910684892258e-11*P0**13 + 1.1150570334480415e-13*P0**14 - 5.991854611667559e-16*P0**15 + 1.4644043461911738e-18*P0**16
    elif P0 > 4.99313436e-4 and P0 <= 0.5658 :
        FED = 0.6596556980482654 + 658.7820465828245*P0 - 3385.412057495701*P0**2 + 8513.26060947245*P0**3 - 7598.179318111917*P0**4
    elif P0 >= 0. and P0 <= 4.99313436e-4 :
        FED = 0.00023360915782327885 + 963.9682663375576*P0 - 6.022287440793628e6*P0**2 + 3.8959199862096825e10*P0**3 - 1.299108445236239e14*P0**4 + 2.097713931761943e17*P0**5 - 1.297185952864878e20*P0**6
    else :
        FED = 0.
    return FED
def sig_beta1e_7_old4(P0,PCC):
    sig = -0.025289589767689545 - 0.043871416138754185*P0 + 0.00019765635295503786*P0**2 - 1.3879637310689232e-6*P0**3 + 4.269131577141152e-9*P0**4 - 6.426655315449915e-12*P0**5 + 3.768403301516009e-15*P0**6
    exper = 1./((PCC/2.5)**(20))
    exper = -exper*(P0-PCC/2)**(20)
    exper = np.exp(exper)
    sig = exper*sig
    return sig

# EOS & anisotropy NS Matter based on GUP; case beta=1e-8
def eden_beta1e_8_old4(P0): 
    if P0>50. :
        FED = 254.4326946197094 + 3.273054555571265*P0 - 0.001997209235201455*P0**2 + 1.8511002328575014e-6*P0**3
    elif P0 > 0.5658 and P0 <= 50. :
        FED = 51.10109700227411 + 29.580374705635396*P0 + 2.5360966788240358*P0**2 - 3.362836320363709*P0**3 + 1.12655537724854*P0**4 - 0.21779082662158694*P0**5 + 0.027827189694289194*P0**6 - 0.0024904123035993414*P0**7 + 0.00016113623644452586*P0**8 - 7.669365209845754e-6*P0**9 + 2.703760430552597e-7*P0**10 - 7.041397888169705e-9*P0**11 + 1.3364159259686347e-10*P0**12 - 1.796211510388538e-12*P0**13 + 1.6192894869877814e-14*P0**14 - 8.779938560531548e-17*P0**15 + 2.1637379362009355e-19*P0**16
    elif P0 > 4.99313436e-4 and P0 <= 0.5658 :
        FED = 0.6596556980482654 + 658.7820465828245*P0 - 3385.412057495701*P0**2 + 8513.26060947245*P0**3 - 7598.179318111917*P0**4
    elif P0 >= 0. and P0 <= 4.99313436e-4 :
        FED = 0.00023360915782327885 + 963.9682663375576*P0 - 6.022287440793628e6*P0**2 + 3.8959199862096825e10*P0**3 - 1.299108445236239e14*P0**4 + 2.097713931761943e17*P0**5 - 1.297185952864878e20*P0**6
    else :
        FED = 0.
    return FED
def sig_beta1e_8_old4(P0,PCC):
    sig = -0.00458706666936496 - 0.004220466683227455*P0 + 0.000018778181142047565*P0**2 - 1.3025426320458175e-7*P0**3 + 3.979182166343163e-10*P0**4 - 5.941766163599393e-13*P0**5 + 3.4541912747099285e-16*P0**6
    exper = 1./((PCC/2.5)**(20))
    exper = -exper*(P0-PCC/2)**(20)
    exper = np.exp(exper)
    sig = exper*sig
    return sig

# EOS & anisotropy NS Matter based on GUP; case beta=1e-9
def eden_beta1e_9_old4(P0): 
    if P0>50. :
        FED = 254.5586443762641 + 3.272343184890167*P0 - 0.0019909310765835776*P0**2 + 1.8446607437157292e-6*P0**3
    elif P0 > 0.5658 and P0 <= 50. :
        FED = 49.34701316942215 + 38.7432329585182*P0 - 6.0207597834429105*P0**2 + 0.5481717031310527*P0**3 + 0.06713032466584544*P0**4 - 0.031123560803850422*P0**5 + 0.005194256595745501*P0**6 - 0.0005321212341344053*P0**7 + 0.00003737764115198022*P0**8 - 1.8799322500754188e-6*P0**9 + 6.894328830278597e-8*P0**10 - 1.8492142295709409e-9*P0**11 + 3.5904038579625506e-11*P0**12 - 4.913125460512138e-13*P0**13 + 4.493677323677699e-15*P0**14 - 2.4654561028157746e-17*P0**15 + 6.135518282983326e-20*P0**16
    elif P0 > 4.99313436e-4 and P0 <= 0.5658 :
        FED = 0.6596556980482654 + 658.7820465828245*P0 - 3385.412057495701*P0**2 + 8513.26060947245*P0**3 - 7598.179318111917*P0**4
    elif P0 >= 0. and P0 <= 4.99313436e-4 :
        FED = 0.00023360915782327885 + 963.9682663375576*P0 - 6.022287440793628e6*P0**2 + 3.8959199862096825e10*P0**3 - 1.299108445236239e14*P0**4 + 2.097713931761943e17*P0**5 - 1.297185952864878e20*P0**6
    else :
        FED = 0.
    return FED
def sig_beta1e_9_old4(P0,PCC):
    sig = -0.0004780677905505392 - 0.0004204666885422772*P0 + 1.869018153246078e-6*P0**2 - 1.2951117047529519e-8*P0**3 + 3.9547110429565084e-11*P0**4 - 5.901970618889158e-14*P0**5 + 3.429024018047249e-17*P0**6
    exper = 1./((PCC/2.5)**(20))
    exper = -exper*(P0-PCC/2)**(20)
    exper = np.exp(exper)
    sig = exper*sig
    return sig

# %%
# hasil fitting terbaru 2022-03-17

# EOS & anisotropy NS Matter based on GUP; case beta=0
def eden_beta0e0(P0): 
    if P0 > 50.000000000000 :
        FED = 254.57247440600295 + 3.2722668135019934*P0 - 0.001990248070884927*P0**2 + 1.84396271672383e-6*P0**3
    elif P0 > 0.5658 and P0 <= 50. :
        FED = 49.26742463817125 + 39.119351704835466*P0 - 6.01896166404222*P0**2 + 0.3433694307027147*P0**3 + 0.18883140341510926*P0**4 - 0.06644121914946151*P0**5 + 0.011485498494705426*P0**6 - 0.001286305935262887*P0**7 + 0.00010130171176109097*P0**8 - 5.822797038254955e-6*P0**9 + 2.4876626925287405e-7*P0**10 - 7.949921889091221e-9*P0**11 + 1.8935665032830884e-10*P0**12 - 3.313041521451298e-12*P0**13 + 4.133738349743126e-14*P0**14 - 3.4808925256755404e-16*P0**15 + 1.772585629917586e-18*P0**16 - 4.1225826164355645e-21*P0**17
    elif P0 > 4.99313436e-4 and P0 <= 0.5658 :
        FED = 0.426006479563915 + 714.2395621878952*P0 - 4571.210848278986*P0**2 + 16153.315408751043*P0**3 - 26410.273422295842*P0**4 + 15662.08708827184*P0**5
    else :
        FED = 0.00023360915782324394 + 963.9682663375585*P0 - 6.022287440793419e6*P0**2 + 3.895919986209412e10*P0**3 - 1.2991084452361116e14*P0**4 + 2.097713931761687e17*P0**5 - 1.2971859528646892e20*P0**6
    return FED
def sig_beta0e0(P0,PCC):
    sig = 0.
    return sig

# EOS & anisotropy NS Matter based on GUP; case beta=1e-7
def eden_beta1e_7(P0): 
    if P0>50. :
        FED = 253.63165216038928 + 3.2752062368565293*P0 - 0.0020475370384748772*P0**2 + 1.9042736185326342e-6*P0**3
    elif P0 > 0.5658 and P0 <= 50. :
        FED = 66.96708993631238 - 56.51471366592033*P0 + 80.53251468579876*P0**2 - 38.23693260439177*P0**3 + 10.427996251960504*P0**4 - 1.8375871943706583*P0**5 + 0.22236347635004453*P0**6 - 0.019184979268615673*P0**7 + 0.001208418519118079*P0**8 - 0.00005632565076844584*P0**9 + 1.952250313381669e-6*P0**10 - 5.012092090517967e-8*P0**11 + 9.3958563916334e-10*P0**12 - 1.2491366788090967e-11*P0**13 + 1.1150846246189833e-13*P0**14 - 5.992007702614946e-16*P0**15 + 1.4644428659331378e-18*P0**16
    elif P0 > 4.99313436e-4 and P0 <= 0.5658 :
        FED = 0.6596556980482822 + 658.7820465828232*P0 - 3385.41205749569*P0**2 + 8513.260609472412*P0**3 - 7598.179318111874*P0**4
    elif P0 >= 0. and P0 <= 4.99313436e-4 :
        FED = 0.00023360915782324394 + 963.9682663375585*P0 - 6.022287440793419e6*P0**2 + 3.895919986209412e10*P0**3 - 1.2991084452361116e14*P0**4 + 2.097713931761687e17*P0**5 - 1.2971859528646892e20*P0**6
    else :
        FED = 0.
    return FED
def sig_beta1e_7(P0,PCC):
    sig = 2.592491577549439 + 1.0881959659546299*P0 - 0.0067339371915666486*P0**2 + 0.00004499403194098332*P0**3 - 1.403890968893791e-7*P0**4 + 2.1380720354225518e-10*P0**5 - 1.2645243593667345e-13*P0**6
    exper = 1./((PCC/2.5)**(20))
    exper = -exper*(P0-PCC/2)**(20)
    exper = np.exp(exper)
    sig = exper*sig
    return sig

# EOS & anisotropy NS Matter based on GUP; case beta=1e-8
def eden_beta1e_8(P0): 
    if P0>50. :
        FED = 254.43269461971036 + 3.273054555571257*P0 - 0.001997209235201446*P0**2 + 1.851100232857492e-6*P0**3
    elif P0 > 0.5658 and P0 <= 50. :
        FED = 51.10110347547388 + 29.580362175576692*P0 + 2.536105893721721*P0**2 - 3.362838524003126*P0**3 + 1.126555289123373*P0**4 - 0.21779067821540893*P0**5 + 0.027827154930995395*P0**6 - 0.00249040782957623*P0**7 + 0.00016113586173675392*P0**8 - 7.669343460675428e-6*P0**9 + 2.7037514338561945e-7*P0**10 - 7.041371129203956e-9*P0**11 + 1.3364102402868038e-10*P0**12 - 1.796203085029556e-12*P0**13 + 1.6192812130330923e-14*P0**14 - 8.779890162813716e-17*P0**15 + 2.1637251708971996e-19*P0**16
    elif P0 > 4.99313436e-4 and P0 <= 0.5658 :
        FED = 0.6596556980482822 + 658.7820465828232*P0 - 3385.41205749569*P0**2 + 8513.260609472412*P0**3 - 7598.179318111874*P0**4
    elif P0 >= 0. and P0 <= 4.99313436e-4 :
        FED = 0.00023360915782324394 + 963.9682663375585*P0 - 6.022287440793419e6*P0**2 + 3.895919986209412e10*P0**3 - 1.2991084452361116e14*P0**4 + 2.097713931761687e17*P0**5 - 1.2971859528646892e20*P0**6
    else :
        FED = 0.
    return FED
def sig_beta1e_8(P0,PCC):
    sig = 0.30701904439652133 + 0.1039495092018227*P0 - 0.0006365506206222362*P0**2 + 4.201612276546197e-6*P0**3 - 1.3005673361001568e-8*P0**4 + 1.9634090417231533e-11*P0**5 - 1.1507021099563144e-14*P0**6
    exper = 1./((PCC/2.5)**(20))
    exper = -exper*(P0-PCC/2)**(20)
    exper = np.exp(exper)
    sig = exper*sig
    return sig

# EOS & anisotropy NS Matter based on GUP; case beta=1e-9
def eden_beta1e_9(P0): 
    if P0>50. :
        FED = 254.55864437626303 + 3.272343184890175*P0 - 0.0019909310765835937*P0**2 + 1.8446607437157493e-6*P0**3
    elif P0 > 0.5658 and P0 <= 50. :
        FED = 49.347044868847675 + 38.74310609538898*P0 - 6.020600747898559*P0**2 + 0.5480790714664272*P0**3 + 0.0671605654123523*P0**4 - 0.031129725932366903*P0**5 + 0.0051950965783228885*P0**6 - 0.0005322011739328282*P0**7 + 0.000037383109189199726*P0**8 - 1.8802057068517032e-6*P0**9 + 6.895336131346411e-8*P0**10 - 1.8494869902025548e-9*P0**11 + 3.590939846404496e-11*P0**12 - 4.913868612157229e-13*P0**13 + 4.494366268951504e-15*P0**14 - 2.4658392016208844e-17*P0**15 + 6.136484238830614e-20*P0**16
    elif P0 > 4.99313436e-4 and P0 <= 0.5658 :
        FED = 0.6596556980482822 + 658.7820465828232*P0 - 3385.41205749569*P0**2 + 8513.260609472412*P0**3 - 7598.179318111874*P0**4
    elif P0 >= 0. and P0 <= 4.99313436e-4 :
        FED = 0.00023360915782324394 + 963.9682663375585*P0 - 6.022287440793419e6*P0**2 + 3.895919986209412e10*P0**3 - 1.2991084452361116e14*P0**4 + 2.097713931761687e17*P0**5 - 1.2971859528646892e20*P0**6
    else :
        FED = 0.
    return FED
def sig_beta1e_9(P0,PCC):
    sig = 0.031145146316513446 + 0.010349211360099742*P0 - 0.00006332850044107077*P0**2 + 4.175962495200208e-7*P0**3 - 1.291925222965174e-9*P0**4 + 1.9491805101749963e-12*P0**5 - 1.1416404376861113e-15*P0**6
    exper = 1./((PCC/2.5)**(20))
    exper = -exper*(P0-PCC/2)**(20)
    exper = np.exp(exper)
    sig = exper*sig
    return sig


# EOS & anisotropy NS Matter based on GUP; case beta=2e-7
def eden_beta2e_7(P0): 
    if P0>50. :
        FED = 200.1258378961289 + 4.358685058266866*P0 - 0.013796121254205849*P0**2 + 0.00005296583197225537*P0**3 - 1.1657052492241307e-7*P0**4 + 1.3492319335389505e-10*P0**5 - 6.354991232878649e-14*P0**6
    elif P0 > 0.5658 and P0 <= 50. :
        FED = 77.61200488948319 - 103.48596798469923*P0 + 108.01042361490993*P0**2 - 47.0534406456691*P0**3 + 12.236392260418553*P0**4 - 2.091411692703887*P0**5 + 0.2477320360518246*P0**6 - 0.02103704030422168*P0**7 + 0.0013087683903057457*P0**8 - 0.00006039398028193877*P0**9 + 2.0757679240446723e-6*P0**10 - 5.290960869264037e-8*P0**11 + 9.856163079580098e-10*P0**12 - 1.3029547656969872e-11*P0**13 + 1.1571813057206772e-13*P0**14 - 6.188973993550857e-16*P0**15 + 1.5059630750270853e-18*P0**16
    elif P0 > 4.99313436e-4 and P0 <= 0.5658 :
        FED = 0.6596556980482654 + 658.7820465828245*P0 - 3385.412057495701*P0**2 + 8513.26060947245*P0**3 - 7598.179318111917*P0**4
    elif P0 >= 0. and P0 <= 4.99313436e-4 :
        FED = 0.00023360915782327885 + 963.9682663375576*P0 - 6.022287440793628e6*P0**2 + 3.8959199862096825e10*P0**3 - 1.299108445236239e14*P0**4 + 2.097713931761943e17*P0**5 - 1.297185952864878e20*P0**6
    else :
        FED = 0.
    return FED
def sig_beta2e_7(P0,PCC):
    sig = -0.019985432882369352 + 0.14583782626004813*P0 - 0.000526911770289466*P0**2 + 3.4213114681827248e-6*P0**3 - 9.611378430855598e-9*P0**4 + 1.3221650201669086e-11*P0**5 - 7.094430444329372e-15*P0**6
    exper = 1./((PCC/2.5)**(20))
    exper = -exper*(P0-PCC/2)**(20)
    exper = np.exp(exper)
    sig = exper*sig
    return sig

# %%
def experiment(P0,PCC):
    exper = 1./((PCC/2.5)**(20))
    exper = -exper*(P0-PCC/2)**(20)
    exper = np.exp(exper)
    return exper

PCC=300
xs = np.linspace(0.,1.*PCC,1000)
ys0 = np.zeros(1000)
for i in range(0,1000,1):
    ys0[i] = experiment(xs[i],PCC)

plt.rcParams["figure.figsize"] = [10.0, 5.0]
plt.rcParams["figure.autolayout"] = True
plt.plot(xs, ys0, linestyle='solid', label=r'$P_c=300$')
plt.xlabel('P')
plt.ylabel(r'$Exp[{-(P-P_c/2)^{20}/(P_c/2.5)^{20}}]$')
plt.legend(loc='best')  # legend text comes from the plot's label parameter.
plt.show()

for i in range(1, 1000):
    print(xs[i], ys0[i], file=open('pengalisigmaGUP.dat', 'a'))
PCC=None

# %%
# plot semua EoS
plt.rcParams["figure.figsize"] = [10.0, 5.0]
plt.rcParams["figure.autolayout"] = True
xs = np.linspace(0.,60.,1000)
ys1 = np.zeros(1000)
ys2 = np.zeros(1000)
ys3 = np.zeros(1000)
ys4 = np.zeros(1000)
ys5 = np.zeros(1000)
for i in range(0,1000,1):
    ys1[i] = eden_beta0e0(xs[i])
    ys2[i] = eden_beta1e_9(xs[i])
    ys3[i] = eden_beta1e_8(xs[i])
    ys4[i] = eden_beta1e_7(xs[i])
    ys5[i] = eden_beta2e_7(xs[i])
plt.plot(xs, ys1, linestyle='solid', label=r'$\beta=0$')
plt.plot(xs, ys2, linestyle='dotted', label=r'$\beta=10^{-9}$')
plt.plot(xs, ys3, linestyle='dashed', label=r'$\beta=10^{-8}$')
plt.plot(xs, ys4, linestyle='dashdot', label=r'$\beta=10^{-7}$')
plt.plot(xs, ys5, linestyle='solid', label=r'$\beta=2\times 10^{-7}$')
plt.title('Perbandingan EoS (new)')
plt.xlabel('P')
plt.ylabel(r'$\epsilon$')
plt.legend(loc='best')  # legend text comes from the plot's label parameter.
plt.show()

if os.path.exists('EoSGUP.dat'):
    os.remove('EoSGUP.dat')
for i in range(1, 1000):
    print(xs[i], ys1[i], ys2[i], ys3[i], ys4[i], file=open('EoSGUP.dat', 'a'))

# %%
# plot semua aniostropi
PCC = 300
plt.rcParams["figure.figsize"] = [10.0, 5.0]
plt.rcParams["figure.autolayout"] = True
xs = np.linspace(0.,1.*PCC,1000)
ys1 = np.zeros(1000)
ys2 = np.zeros(1000)
ys3 = np.zeros(1000)
ys4 = np.zeros(1000)
ys5 = np.zeros(1000)
for i in range(0,1000,1):
    ys1[i] = sig_beta0e0(xs[i],PCC)
    ys2[i] = sig_beta1e_9(xs[i],PCC)
    ys3[i] = sig_beta1e_8(xs[i],PCC)
    ys4[i] = sig_beta1e_7(xs[i],PCC)
    ys5[i] = sig_beta2e_7(xs[i],PCC)
plt.plot(xs, ys1, linestyle='solid', label=r'$\beta=0$')
plt.plot(xs, ys2, linestyle='dotted', label=r'$\beta=10^{-9}$')
plt.plot(xs, ys3, linestyle='dashed', label=r'$\beta=10^{-8}$')
plt.plot(xs, ys4, linestyle='dashdot', label=r'$\beta=10^{-7}$')
plt.plot(xs, ys5, linestyle='solid', label=r'$\beta=2\times 10^{-7}$')
plt.title(r'Perbandingan $\sigma$ (new)')
plt.xlabel('P')
plt.ylabel(r'$\sigma$')
plt.legend(loc='best')  # legend text comes from the plot's label parameter.
plt.show()

if os.path.exists('sigmaGUP.dat'):
    os.remove('sigmaGUP.dat')
for i in range(1, 1000):
    print(xs[i], ys1[i], ys2[i], ys3[i], ys4[i], ys5[i], file=open('sigmaGUP.dat', 'a'))

PCC = None
